# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
telefonRehberi = {"Ahmet": "0532 678 13 19","Mehmet": "0543 234 56 78","Ayşe": "0555 987 65 43","Fatma": "0566 123 45 67"}

isim = input("Lütfen numarasini öğrenmek istediğiniz kişinin adini girin: ")

if isim in telefonRehberi:
    print(f"{isim} isimli kişinin numarasi: {telefonRehberi[isim]}")
else:
    print(f"{isim} isimli kişi rehberde bulunamadi.")
# Out:
# Ayşe isimli kişinin numarasi: 0555 987 65 43

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
calisanlarİndeksi = {"Mehmet Yağız": ["Adana", 40, "Direktör"],"Ahmet Yılmaz": ["İstanbul", 35, "Müdür"],"Ayşe Kaya": ["Ankara", 29, "Mühendis"],"Fatma Demir": ["İzmir", 31, "Analist"]}

isim = input("Lütfen bilgilerini görüntülemek istediğiniz çalişanin ismini girin: ")

if isim in calisanlarİndeksi:
    memleket, yas, gorev = calisanlarİndeksi[isim]
    print(f"{isim} = Memleket: {memleket} Yaş: {yas} Görev: {gorev}")
else:
    print(f"{isim} isimli çalişan bulunamadi.")
# Out:
# Ayşe Kaya = Memleket: Ankara Yaş: 29 Görev: Mühendis

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
ogrenciNotlari = {"Mehmet": [72, 66, 48],"Ahmet": [85, 78, 92],"Ayşe": [88, 79, 85]}

isim = input("Lütfen notlarini görmek istediğiniz öğrencinin adini girin: ")

if isim in ogrenciNotlari:
    notlar = ogrenciNotlari[isim]
    ortalama = sum(notlar) / len(notlar)
    print(f"{isim} isimli öğrencinin notlari:")
    for i, notu in enumerate(notlar, 1):
        print(f"{i}. Sinav Notu: {notu}")
    print(f"Not Ortalamasi: {ortalama:.1f}")
else:
    print(f"{isim} isimli öğrenci bulunamadi.")
# Out:
# Ayşe isimli öğrencinin notlari:
# 1. Sinav Notu: 88
# 2. Sinav Notu: 79
# 3. Sinav Notu: 85
# Not Ortalamasi: 84.0

# %% [markdown]
# # Problem 4

# %%
# Listeyi oluşturun
araclar = ["Bmw", "Mercedes", "Opel", "Mazda"]

# 2 - Liste kaç elemanlıdır?
print(f"Liste {len(araclar)} elemanlıdır.")

# 3 - Listenin ilk ve son elemanı nedir?
print(f"Listenin ilk elemanı: {araclar[0]}")
print(f"Listenin son elemanı: {araclar[-1]}")

# 4 - Mazda değerini Toyota ile değiştirin.
araclar[-1] = "Toyota"
print("Mazda değeri Toyota ile değiştirildi:", araclar)

# 5 - Listenin -2 indeksindeki değer nedir?
print("Listenin -2 indeksindeki değer:", araclar[-2])

# 6 - Listenin ilk 3 elemanını alın.
print("Listenin ilk 3 elemanı:", araclar[:3])

# 7 - Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
araclar[-2:] = ["Toyota", "Renault"]
print("Son 2 eleman yerine 'Toyota' ve 'Renault' eklendi:", araclar)

# 8 - Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
araclar.extend(["Audi", "Nissan"])
print("Listeye 'Audi' ve 'Nissan' eklendi:", araclar)

# 9 - Listenin son elemanını silin.
araclar.pop()
print("Listenin son elemanı silindi:", araclar)

# 10 - Liste elemanlarını tersten yazdırınız.
print("Liste elemanları tersten:", list(reversed(araclar)))

# 11 - Aşağıdaki verileri bir liste içinde saklayınız.
# studentA: Yiğit Bilgi 2010, (70, 60, 70)
# studentB: Sena Turan 1999, (80, 80, 70)
# studentC: Ahmet Turan 1998, (80, 70, 90)
students = [
    {"name": "Yiğit Bilgi", "year": 2010, "scores": (70, 60, 70)},
    {"name": "Sena Turan", "year": 1999, "scores": (80, 80, 70)},
    {"name": "Ahmet Turan", "year": 1998, "scores": (80, 70, 90)}
]
print("Öğrenci verileri:", students)

# 12 - Liste elemanlarını ekrana yazdırınız.
names = ['Ali', 'Yağmur', 'Hakan', 'Deniz']
years = [1998, 2000, 1998, 1987]
print("İsimler:", names)
print("Yıllar:", years)

# 13 - "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
print("Cenk eklendi:", names)

# 14 - "Sena" değerini listenin başına ekleyiniz.
names.insert(0, "Sena")
print("Sena başa eklendi:", names)

# 15 - "Deniz" ismini listeden siliniz.
names.remove("Deniz")
print("Deniz silindi:", names)

# 16 - "Ali" listenin bir elemanı mıdır?
print("Ali listenin bir elemanı mı?", "Ali" in names)

# 17 - Liste elemanlarını ters çevirin.
names.reverse()
print("Liste ters çevrildi:", names)

# 18 - Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
print("Liste alfabetik olarak sıralandı:", names)

# 19 - years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()
print("Years listesi rakamsal büyüklüğe göre sıralandı:", years)

# 20 - str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
car_brands = "Chevrolet,Dacia".split(",")
print("Karakter dizisi listeye çevrildi:", car_brands)

# 21 - years dizisinde kaç tane 1998 değeri vardır?
count_1998 = years.count(1998)
print("Years dizisinde kaç tane 1998 değeri var:", count_1998)

# 22 - years dizisinin tüm elemanlarını siliniz.
years.clear()
print("Years dizisinin tüm elemanları silindi:", years)

# 23 - Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
newBrands = []
for _ in range(3):
    brand = input("Bir marka ismi girin: ")
    newBrands.append(brand)
print("Girilen markalar:", newBrands)
# Out:
# Liste 4 elemanlıdır.
# Listenin ilk elemanı: Bmw
# Listenin son elemanı: Mazda
# Mazda değeri Toyota ile değiştirildi: ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Listenin -2 indeksindeki değer: Opel
# Listenin ilk 3 elemanı: ['Bmw', 'Mercedes', 'Opel']
# Son 2 eleman yerine 'Toyota' ve 'Renault' eklendi: ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# Listeye 'Audi' ve 'Nissan' eklendi: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# Listenin son elemanı silindi: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# Liste elemanları tersten: ['Audi', 'Renault', 'Toyota', 'Mercedes', 'Bmw']
# Öğrenci verileri: [{'name': 'Yiğit Bilgi', 'year': 2010, 'scores': (70, 60, 70)}, {'name': 'Sena Turan', 'year': 1999, 'scores': (80, 80, 70)}, {'name': 'Ahmet Turan', 'year': 1998, 'scores': (80, 70, 90)}]
# İsimler: ['Ali', 'Yağmur', 'Hakan', 'Deniz']
# Yıllar: [1998, 2000, 1998, 1987]
# Cenk eklendi: ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# Sena başa eklendi: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# Deniz silindi: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# Ali listenin bir elemanı mı? True
# Liste ters çevrildi: ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# Liste alfabetik olarak sıralandı: ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# Years listesi rakamsal büyüklüğe göre sıralandı: [1987, 1998, 1998, 2000]
# Karakter dizisi listeye çevrildi: ['Chevrolet', 'Dacia']
# Years dizisinde kaç tane 1998 değeri var: 2
# Years dizisinin tüm elemanları silindi: []
# Girilen markalar: ['bmw', 'mercedes', 'audi']
